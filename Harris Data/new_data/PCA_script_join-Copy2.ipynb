# %%
#Import data
import pandas as pd
DATAFILE = "./prepared_data/join_binary_scale.csv"
Purchase_DF = pd.read_csv(DATAFILE)
print(list(Purchase_DF))
Purchase_DF
# Out:
# ['mean_unexpcost', 'median_unexpcost', 'mean_stdcost', 'median_stdcost', 'mean_pocost', 'median_pocost', 'mean_qty', 'median_qty', 'mean_costsave', 'median_costsave', 'mean_spend', 'median_spend', 'mean_return_spend', 'median_return_spend', 'mean_leadtime', 'median_leadtime', 'mean_abc', 'median_abc', 'mean_source', 'median_source', 'Category', 'mean_late', 'median_late', 'mean_early', 'median_early', '%Critical', 'SupplierID', 'quality_risk_mean', 'quality_risk_median', 'delivery_risk_mean', 'delivery_risk_median']
#      mean_unexpcost  median_unexpcost  mean_stdcost  median_stdcost  \
# 0          2.000000               2.0      2.000000             2.0
# 1          1.000000               1.0      2.000000             2.0
# 2          1.000000               1.0      1.000000             1.0
# 3          1.121053               1.0      2.000000             2.0
# 4          1.666667               2.0      1.111111             1.0
# 5          1.894737               2.0      2.000000             2.0
# 6          1.166667               1.0      2.000000             2.0
# 7          1.000000               1.0      1.000000             1.0
# 8          1.000000               1.0      2.000000             2.0
# 9          1.333333               1.0      2.000000             2.0
# 10         1.363636               1.0      1.818182             2.0
# 11         2.000000               2.0      2.000000             2.0
# 12         1.166667               1.0      1.000000             1.0
# 13         1.470588               1.0      1.000000             1.0
# 14         1.305795               1.0      1.129470             1.0
# 15         1.500000               1.5      1.000000             1.0
# 16         1.000000               1.0      2.000000             2.0
# 17         1.500000               1.5      2.000000             2.0
# 18         1.239544               1.0      1.182510             1.0
# 19         1.260000               1.0      1.340000             1.0
# 20         1.555556               2.0      1.222222             1.0
# 21         1.000000               1.0      2.000000             2.0
# 22         1.333333               1.0      2.000000             2.0
# 23         1.666667               2.0      2.000000             2.0
# 24         2.000000               2.0      1.000000             1.0
# 25         2.000000               2.0      1.000000             1.0
# 26         1.750000               2.0      1.000000             1.0
# 27         1.000000               1.0      1.000000             1.0
# 28         1.375000               1.0      2.000000             2.0
# 29         1.000000               1.0      1.000000             1.0
# ..              ...               ...           ...             ...
# 548        2.000000               2.0      1.000000             1.0
# 549        1.705882               2.0      1.647059             2.0
# 550        1.257895               1.0      1.926316             2.0
# 551        1.000000               1.0      2.000000             2.0
# 552        1.416667               1.0      2.000000             2.0
# 553        1.000000               1.0      1.000000             1.0
# 554        1.345238               1.0      1.071429             1.0
# 555        1.373563               1.0      1.383142             1.0
# 556        1.000000               1.0      1.200000             1.0
# 557        1.000000               1.0      1.000000             1.0
# 558        1.357143               1.0      1.285714             1.0
# 559        1.428571               1.0      2.000000             2.0
# 560        1.705882               2.0      2.000000             2.0
# 561        1.000000               1.0      1.729167             2.0
# 562        1.000000               1.0      2.000000             2.0
# 563        1.909091               2.0      1.000000             1.0
# 564        1.144231               1.0      1.105769             1.0
# 565        1.555556               2.0      2.000000             2.0
# 566        1.375000               1.0      2.000000             2.0
# 567        2.000000               2.0      2.000000             2.0
# 568        1.000000               1.0      1.000000             1.0
# 569        1.283019               1.0      2.000000             2.0
# 12                   1.0            1.416667                   1.0
# 13                   1.0            1.416667                   1.0
# 14                   1.0            1.416667                   1.0
# 15                   1.0            1.416667                   1.0
# 16                   1.0            1.333333                   1.0
# 17                   1.0            1.250000                   1.0
# 18                   1.0            1.250000                   1.0
# 19                   1.0            1.250000                   1.0
# 20                   1.0            1.250000                   1.0
# 21                   1.0            1.307692                   1.0
# 22                   1.0            1.307692                   1.0
# 23                   1.0            1.000000                   1.0
# 24                   1.0            1.000000                   1.0
# 25                   1.0            1.000000                   1.0
# 26                   1.0            1.000000                   1.0
# 27                   1.0            1.000000                   1.0
# 28                   1.0            1.666667                   2.0
# 29                   1.0            1.666667                   2.0
# ..                   ...                 ...                   ...
# 548                  1.0            1.333333                   1.0
# 549                  1.5            2.000000                   2.0
# 550                  1.0            1.590909                   2.0
# 551                  1.0            1.590909                   2.0
# 552                  1.0            1.090909                   1.0
# 553                  1.0            1.200000                   1.0
# 554                  1.0            1.083333                   1.0
# 555                  1.0            1.083333                   1.0
# 556                  1.0            1.083333                   1.0
# 557                  1.0            1.083333                   1.0
# 558                  1.0            1.083333                   1.0
# 559                  1.0            1.666667                   2.0
# 560                  1.0            1.666667                   2.0
# 561                  1.0            1.400000                   1.0
# 562                  1.0            1.000000                   1.0
# 563                  1.0            1.555556                   2.0
# 564                  1.0            1.555556                   2.0
# 565                  1.0            1.000000                   1.0
# 566                  1.0            1.000000                   1.0
# 567                  1.0            1.250000                   1.0
# 568                  1.0            1.000000                   1.0
# 569                  1.0            1.888889                   2.0
# 570                  1.0            1.000000                   1.0
# 571                  2.0            1.000000                   1.0
# 572                  1.0            1.250000                   1.0
# 573                  1.0            1.500000                   1.5
# 574                  1.0            1.200000                   1.0
# 575                  1.0            1.000000                   1.0
# 576                  1.0            1.333333                   1.0
# 577                  1.0            2.000000                   2.0
#
# [578 rows x 31 columns]

# %%
df = pd.read_csv("./original_data/Purchasing_Tool_FY16-FY18_2018-11-16.csv")
print(list(df))
# Out:
# ['Supplier ID', 'PO', 'Line', 'Shipment', 'Release', 'StdCost', 'PoCost', 'BuyerNumber', 'BuyProgram', 'BuyerName', 'Part', 'Description', 'Qty', 'ReceiverNumber', 'SupplierID', 'Year', 'Period', 'Week', 'Qtr', 'CommodityLevel1', 'CommodityLevel2', 'CommodityLevel3', 'InternalCostSavings', 'Spend', 'ForecastType', 'PurchLeadTime', 'ABC', 'PaymentTerm', 'SupplierClassification', 'Category', 'PoPlacedDate', 'PoPlacedYear', 'Org_Code', 'SupplierSite']

# %%
dtypes1 = ['StdCost', 'PoCost', 'Qty', 'InternalCostSavings', 'Spend', 'PurchLeadTime', 'ABC']

# %%
# df = df[dtypes1]
df = df.dropna()
df.corr()
# Out:
#                            PO      Line  Shipment   Release   StdCost  \
# PO                   1.000000  0.055398  0.034010 -0.253271  0.131677
# Line                 0.055398  1.000000  0.131130  0.330762 -0.100697
# Shipment             0.034010  0.131130  1.000000  0.034076 -0.010968
# Release             -0.253271  0.330762  0.034076  1.000000 -0.141283
# StdCost              0.131677 -0.100697 -0.010968 -0.141283  1.000000
# PoCost               0.130904 -0.102486 -0.012208 -0.142052  0.999673
# Qty                 -0.089214 -0.095374 -0.040461 -0.009700 -0.104953
# SupplierID           0.355246 -0.027047  0.012254 -0.103625  0.154469
# Year                 0.282322  0.081425 -0.038865  0.348574  0.006771
# InternalCostSavings  0.069756 -0.010225  0.006659 -0.043739  0.181464
# Spend                0.017565 -0.056404 -0.009434 -0.039307  0.272488
# PurchLeadTime        0.192469  0.258489  0.062259 -0.031701  0.231765
# PoPlacedYear         0.282322  0.081425 -0.038865  0.348574  0.006771
#
#                        PoCost       Qty  SupplierID      Year  \
# PO                   0.130904 -0.089214    0.355246  0.282322
# Line                -0.102486 -0.095374   -0.027047  0.081425
# Shipment            -0.012208 -0.040461    0.012254 -0.038865
# Release             -0.142052 -0.009700   -0.103625  0.348574
# StdCost              0.999673 -0.104953    0.154469  0.006771
# PoCost               1.000000 -0.105061    0.153755  0.005946
# Qty                 -0.105061  1.000000   -0.012406 -0.001997
# SupplierID           0.153755 -0.012406    1.000000  0.108215
# Year                 0.005946 -0.001997    0.108215  1.000000
# InternalCostSavings  0.179851 -0.005350    0.028455  0.004112
# Spend                0.272955  0.018607   -0.006691 -0.003650
# PurchLeadTime        0.231651 -0.120198    0.013936  0.038620
# PoPlacedYear         0.005946 -0.001997    0.108215  1.000000
#
#                      InternalCostSavings     Spend  PurchLeadTime  \
# PO                              0.069756  0.017565       0.192469
# Line                           -0.010225 -0.056404       0.258489
# Shipment                        0.006659 -0.009434       0.062259
# Release                        -0.043739 -0.039307      -0.031701
# StdCost                         0.181464  0.272488       0.231765
# PoCost                          0.179851  0.272955       0.231651
# Qty                            -0.005350  0.018607      -0.120198
# SupplierID                      0.028455 -0.006691       0.013936
# Year                            0.004112 -0.003650       0.038620
# InternalCostSavings             1.000000  0.569907      -0.018403
# Spend                           0.569907  1.000000       0.063243
# PurchLeadTime                  -0.018403  0.063243       1.000000
# PoPlacedYear                    0.004112 -0.003650       0.038620
#
#                      PoPlacedYear
# PO                       0.282322
# Line                     0.081425
# Shipment                -0.038865
# Release                  0.348574
# StdCost                  0.006771
# PoCost                   0.005946
# Qty                     -0.001997
# SupplierID               0.108215
# Year                     1.000000
# InternalCostSavings      0.004112
# Spend                   -0.003650
# PurchLeadTime            0.038620
# PoPlacedYear             1.000000

# %%
dtypes = ['mean_unexpcost', 'mean_return_spend', 'mean_qty', 'mean_costsave', 'mean_spend',
             'mean_leadtime','mean_abc', 'mean_source',
             'mean_late', 'mean_early','%Critical', 'quality_risk_mean', 'delivery_risk_mean']
df = Purchase_DF[dtypes]
dtypes = ['mean_unexpcost', 'median_unexpcost', 'mean_stdcost', 'median_stdcost', 'mean_pocost', 'median_pocost', 'mean_qty', 'median_qty', 'mean_costsave', 'median_costsave', 'mean_spend', 'median_spend', 'mean_return_spend', 'median_return_spend', 'mean_leadtime', 'median_leadtime', 'mean_abc', 'median_abc', 'mean_source', 'median_source', 'Category', 'mean_late', 'mean_early', 'median_early', '%Critical', 'SupplierID', 'quality_risk_mean', 'quality_risk_median', 'delivery_risk_mean', 'delivery_risk_median']
df = Purchase_DF[dtypes]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# calculate the correlation matrix
corr = df.corr()

# plot the heatmap

a4_dims = (20, 12)
fig, ax = plt.subplots(figsize=a4_dims)
plt.title('Corr Matrix Purchasing Tool', fontsize=30)
plt.xlabel('number of components', fontsize=30)
plt.ylabel('cumulative explained variance', fontsize=30)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.tick_params(axis='both', which='minor', labelsize=20)
sns.heatmap(corr, annot=False,
        xticklabels=corr.columns,
        yticklabels=corr.columns)
plt.tight_layout()
plt.savefig("Corr_PT1")

# %%
#  plt.figure(figsize=(20,12))
#     plt.scatter(projected[:, 0], projected[:, 1],
#                 c=x[feat], edgecolor='none', alpha=0.5,
#                 cmap=plt.cm.get_cmap('copper', 10))
#     plt.xlabel('component 1', fontsize=30)
#     plt.ylabel('component 2', fontsize=30)
#     plt.tick_params(axis='both', which='major', labelsize=20)
#     plt.tick_params(axis='both', which='minor', labelsize=20)
#     plt.title(file+" bin "+feat, fontsize=30)
#     plt.colorbar();
#     fname = method+"_"+file+"_1_2_" + feat
#     plt.savefig(fname)
#     plt.show()
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns; sns.set()
# import math

purchasing = Purchase_DF
purchasing2 = purchasing.drop(list(purchasing[purchasing['mean_late'] <= 1].index), axis = 0)


plt.figure(figsize=(20,12))
plt.hist(purchasing2['mean_late'], bins = 15)
plt.title('mean_late > 1', fontsize=30)
plt.xlabel('mean_late', fontsize=30)
plt.ylabel('count', fontsize=30)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.tick_params(axis='both', which='minor', labelsize=20)

#fname = "distr/" + feat + "_distr"
plt.savefig('mean_late2')
plt.show()

# %%
plt.show()

# %%
#Select features
# PCA_feats = ['mean_unexpcost', 'mean_return_spend', 'mean_qty', 'mean_costsave', 'mean_spend',
#              'mean_leadtime','mean_abc', 'mean_source',
#              'mean_late', 'mean_early','%Critical', 'quality_risk_mean', 'delivery_risk_mean']
PCA_feats = ['mean_unexpcost', 'mean_return_spend','mean_spend',
             'mean_late', 'mean_early','%Critical', 'quality_risk_mean', 'delivery_risk_mean']
Purch_PCA = Purchase_DF[PCA_feats]
Purch_PCA = Purch_PCA.dropna()

# %%
Purchase_DF.corr()
# Out:
#                       mean_unexpcost  median_unexpcost  mean_stdcost  \
# mean_unexpcost              1.000000          0.857138     -0.025261
# median_unexpcost            0.857138          1.000000      0.001937
# mean_stdcost               -0.025261          0.001937      1.000000
# median_stdcost             -0.011400          0.024571      0.960849
# mean_pocost                 0.014664          0.045091      0.962770
# median_pocost               0.032692          0.070866      0.922170
# mean_qty                    0.039258          0.009717     -0.588821
# median_qty                  0.045707          0.014197     -0.564417
# mean_costsave               0.009202          0.052456      0.053318
# median_costsave             0.069346          0.068416      0.056620
# mean_spend                 -0.022221          0.001876      0.459345
# median_spend               -0.003247          0.018982      0.368164
# mean_return_spend          -0.016658         -0.015839      0.129073
# median_return_spend        -0.039239         -0.022004      0.037905
# mean_leadtime               0.019343          0.044490      0.112581
# median_leadtime             0.021761          0.063600      0.113605
# mean_abc                   -0.024836         -0.025184      0.323718
# median_abc                 -0.029612         -0.014584      0.295916
# mean_source                -0.303145         -0.258092      0.092235
# median_source              -0.285308         -0.256340      0.067221
# mean_late                   0.016550          0.023414      0.003429
# median_late                      NaN               NaN           NaN
# mean_early                 -0.013382          0.009164      0.116411
# median_early               -0.013645         -0.020719      0.117197
# %Critical                  -0.029945         -0.029238      0.188057
# SupplierID                  0.132820          0.089430      0.081952
# quality_risk_mean          -0.076493         -0.079793      0.147889
# quality_risk_median         0.051847          0.049962      0.047954
# delivery_risk_mean          0.025996          0.015888      0.079647
# delivery_risk_median        0.086186          0.080006      0.106756
#
#                       median_stdcost  mean_pocost  median_pocost  mean_qty  \
# mean_unexpcost             -0.011400     0.014664       0.032692  0.039258
# median_unexpcost            0.024571     0.045091       0.070866  0.009717
# mean_stdcost                0.960849     0.962770       0.922170 -0.588821
# median_stdcost              1.000000     0.925889       0.950204 -0.563417
# mean_pocost                 0.925889     1.000000       0.959733 -0.615595
# median_pocost               0.950204     0.959733       1.000000 -0.578117
# mean_qty                   -0.563417    -0.615595      -0.578117  1.000000
# median_qty                 -0.554866    -0.584288      -0.557958  0.911807
# mean_costsave               0.046900     0.078434       0.073441 -0.225799
# median_costsave             0.054740     0.075558       0.069025 -0.150577
# mean_spend                  0.435896     0.449378       0.432858 -0.067595
# median_spend                0.343821     0.364862       0.353563 -0.060657
# mean_return_spend           0.128619     0.132228       0.132088 -0.150591
# median_return_spend         0.034648     0.036660       0.033209 -0.046503
# mean_leadtime               0.103832     0.109906       0.110884  0.033518
# median_leadtime             0.101558     0.114349       0.116853  0.038862
# mean_abc                    0.315273     0.311083       0.308531  0.014294
# median_abc                  0.291300     0.285304       0.285286  0.020034
# mean_source                 0.074412     0.069738       0.045183 -0.087390
# median_source               0.043405     0.045845       0.018895 -0.085790
# mean_late                   0.015762     0.006469       0.026210 -0.051210
# median_late                      NaN          NaN            NaN       NaN
# mean_early                  0.097501     0.135021       0.114908 -0.058844
# median_early                0.095210     0.125349       0.102540 -0.039957
# %Critical                   0.193653     0.186509       0.189238 -0.110256
# SupplierID                  0.072558     0.071966       0.065687 -0.045890
# quality_risk_mean           0.148039     0.157380       0.153393 -0.170170
# quality_risk_median         0.056661     0.046921       0.054309 -0.060066
# delivery_risk_mean          0.111119     0.112062       0.148869 -0.087182
# delivery_risk_median        0.132092     0.134635       0.169849 -0.094543
#
#                       median_qty  mean_costsave  median_costsave  \
# mean_unexpcost          0.045707       0.009202         0.069346
# median_unexpcost        0.014197       0.052456         0.068416
# mean_stdcost           -0.564417       0.053318         0.056620
# median_stdcost         -0.554866       0.046900         0.054740
# mean_pocost            -0.584288       0.078434         0.075558
# median_pocost          -0.557958       0.073441         0.069025
# mean_qty                0.911807      -0.225799        -0.150577
# median_qty              1.000000      -0.190385        -0.127551
# mean_costsave          -0.190385       1.000000         0.831403
# median_costsave        -0.127551       0.831403         1.000000
# mean_spend             -0.061138      -0.085038        -0.063628
# median_spend           -0.030338      -0.068328        -0.080027
# mean_return_spend      -0.134699      -0.035856         0.023115
# median_return_spend    -0.035649      -0.038948        -0.038820
# mean_leadtime           0.033778      -0.002084        -0.023079
# median_leadtime         0.043050      -0.004377        -0.034831
# mean_abc                0.017506      -0.134695        -0.102611
# median_abc              0.036950      -0.095783        -0.075237
# mean_source            -0.098401       0.164704         0.100277
# median_source          -0.085299       0.143802         0.083749
# mean_late              -0.037041       0.019697         0.032727
# median_late                  NaN            NaN              NaN
# mean_early             -0.055563      -0.034333        -0.013460
# median_early           -0.033567      -0.039378         0.013845
# %Critical              -0.110913      -0.048909         0.003093
# SupplierID             -0.032919      -0.069216        -0.031977
# quality_risk_mean      -0.180659       0.052645         0.061700
# quality_risk_median    -0.058298       0.036176         0.031087
# delivery_risk_mean     -0.091101       0.038483         0.065409
# delivery_risk_median   -0.110206       0.023981         0.060694
#
#                               ...           mean_late  median_late  \
# mean_unexpcost                ...            0.016550          NaN
# median_unexpcost              ...            0.023414          NaN
# mean_stdcost                  ...            0.003429          NaN
# median_stdcost                ...            0.015762          NaN
# mean_pocost                   ...            0.006469          NaN
# median_pocost                 ...            0.026210          NaN
# mean_qty                      ...           -0.051210          NaN
# median_qty                    ...           -0.037041          NaN
# mean_costsave                 ...            0.019697          NaN
# median_costsave               ...            0.032727          NaN
# mean_spend                    ...           -0.033891          NaN
# median_spend                  ...           -0.031672          NaN
# mean_return_spend             ...            0.009338          NaN
# median_return_spend           ...           -0.007024          NaN
# mean_leadtime                 ...           -0.021809          NaN
# median_leadtime               ...           -0.030131          NaN
# mean_abc                      ...           -0.005861          NaN
# median_abc                    ...           -0.002851          NaN
# mean_source                   ...            0.045461          NaN
# median_source                 ...            0.038364          NaN
# mean_late                     ...            1.000000          NaN
# median_late                   ...                 NaN          NaN
# mean_early                    ...           -0.275949          NaN
# median_early                  ...           -0.259476          NaN
# %Critical                     ...            0.070819          NaN
# SupplierID                    ...           -0.013609          NaN
# quality_risk_mean             ...            0.025330          NaN
# quality_risk_median           ...           -0.011486          NaN
# delivery_risk_mean            ...            0.062267          NaN
# delivery_risk_median          ...            0.025001          NaN
#
#                       mean_early  median_early  %Critical  SupplierID  \
# mean_unexpcost         -0.013382     -0.013645  -0.029945    0.132820
# median_unexpcost        0.009164     -0.020719  -0.029238    0.089430
# mean_stdcost            0.116411      0.117197   0.188057    0.081952
# median_stdcost          0.097501      0.095210   0.193653    0.072558
# mean_pocost             0.135021      0.125349   0.186509    0.071966
# median_pocost           0.114908      0.102540   0.189238    0.065687
# mean_qty               -0.058844     -0.039957  -0.110256   -0.045890
# median_qty             -0.055563     -0.033567  -0.110913   -0.032919
# mean_costsave          -0.034333     -0.039378  -0.048909   -0.069216
# median_costsave        -0.013460      0.013845   0.003093   -0.031977
# mean_spend              0.117527      0.081530   0.182411    0.024260
# median_spend            0.116248      0.070428   0.135994    0.000487
# mean_return_spend       0.043114      0.056785   0.099539    0.041285
# median_return_spend     0.017445      0.006630  -0.019956   -0.020631
# mean_leadtime           0.074571      0.040964   0.046265    0.054213
# median_leadtime         0.095303      0.037978   0.028328    0.065993
# mean_abc                0.046177      0.060995   0.137709    0.018883
# median_abc              0.043390      0.051223   0.116993    0.019425
# mean_source            -0.017734     -0.003399   0.079060   -0.298086
# median_source          -0.011809     -0.003876   0.091810   -0.274869
# mean_late              -0.275949     -0.259476   0.070819   -0.013609
# median_late                  NaN           NaN        NaN         NaN
# mean_early              1.000000      0.863667   0.034800    0.034481
# median_early            0.863667      1.000000   0.023050   -0.015792
# %Critical               0.034800      0.023050   1.000000    0.039886
# SupplierID              0.034481     -0.015792   0.039886    1.000000
# quality_risk_mean       0.036249      0.008604   0.084617    0.044966
# quality_risk_median     0.022117      0.010842   0.011030    0.162600
# delivery_risk_mean      0.006836     -0.000103   0.134905    0.100799
# delivery_risk_median    0.008113     -0.003725   0.115848    0.158228
#
#                       quality_risk_mean  quality_risk_median  \
# mean_unexpcost                -0.076493             0.051847
# median_unexpcost              -0.079793             0.049962
# mean_stdcost                   0.147889             0.047954
# median_stdcost                 0.148039             0.056661
# mean_pocost                    0.157380             0.046921
# median_pocost                  0.153393             0.054309
# mean_qty                      -0.170170            -0.060066
# median_qty                    -0.180659            -0.058298
# mean_costsave                  0.052645             0.036176
# median_costsave                0.061700             0.031087
# mean_spend                     0.028848            -0.049505
# median_spend                  -0.000656            -0.033892
# mean_return_spend              0.097173             0.011253
# median_return_spend           -0.020025            -0.002834
# mean_leadtime                 -0.004148            -0.022063
# median_leadtime                0.005126            -0.004526
# mean_abc                      -0.014119            -0.037223
# median_abc                    -0.015653            -0.030005
# mean_source                    0.031989             0.025722
# median_source                  0.016248             0.021484
# mean_late                      0.025330            -0.011486
# median_late                         NaN                  NaN
# mean_early                     0.036249             0.022117
# median_early                   0.008604             0.010842
# %Critical                      0.084617             0.011030
# SupplierID                     0.044966             0.162600
# quality_risk_mean              1.000000             0.577317
# quality_risk_median            0.577317             1.000000
# delivery_risk_mean             0.264757             0.032530
# delivery_risk_median           0.203385             0.034046
#
#                       delivery_risk_mean  delivery_risk_median
# mean_unexpcost                  0.025996              0.086186
# median_unexpcost                0.015888              0.080006
# mean_stdcost                    0.079647              0.106756
# median_stdcost                  0.111119              0.132092
# mean_pocost                     0.112062              0.134635
# median_pocost                   0.148869              0.169849
# mean_qty                       -0.087182             -0.094543
# median_qty                     -0.091101             -0.110206
# mean_costsave                   0.038483              0.023981
# median_costsave                 0.065409              0.060694
# mean_spend                     -0.059277             -0.036279
# median_spend                   -0.087905             -0.070812
# mean_return_spend               0.098834              0.068469
# median_return_spend            -0.043548             -0.020675
# mean_leadtime                  -0.000129              0.016194
# median_leadtime                -0.021579             -0.004433
# mean_abc                        0.032383              0.052146
# median_abc                      0.021804              0.020441
# mean_source                    -0.087647             -0.126554
# median_source                  -0.096779             -0.132337
# mean_late                       0.062267              0.025001
# median_late                          NaN                   NaN
# mean_early                      0.006836              0.008113
# median_early                   -0.000103             -0.003725
# %Critical                       0.134905              0.115848
# SupplierID                      0.100799              0.158228
# quality_risk_mean               0.264757              0.203385
# quality_risk_median             0.032530              0.034046
# delivery_risk_mean              1.000000              0.840808
# delivery_risk_median            0.840808              1.000000
#
# [30 rows x 30 columns]

# %%
#PCA Script + Run
from sklearn.decomposition import PCA
import numpy as np
def PCA_method(data):
    pca_model = PCA()
    pca_model.n_components = 6
    pca_fit = pca_model.fit(data)
    print("explained variance")
    print(pca_fit.explained_variance_ratio_)
    var_sum = sum(pca_fit.explained_variance_ratio_)
    print([p for p in pca_fit.explained_variance_ratio_])
    
    print("components")
    # matrix of size n_components X n_features
    # a_i,j tells how much the jth feature contributed to the ith component
    comp = pca_fit.components_
    print(comp)
    # summing along columns tells how much each feature contributes overall
    comp_sum = np.sum(comp, axis = 0)
    print(comp_sum)
    return pca_fit
pca=PCA_method(Purch_PCA) 
comp = pca.components_
params = pca.explained_variance_ratio_
# Out:
# explained variance
# [0.38006866 0.21367683 0.20452925 0.1360133  0.04114599 0.01516192]
# [0.38006865702344644, 0.21367683176471744, 0.20452924722928637, 0.1360133032627898, 0.041145988804690774, 0.015161919922028467]
# components
# [[-0.0528172   0.01868061  0.29123217  0.00376427  0.02201935  0.94803798
#    0.02315599  0.11060731]
#  [ 0.89852575 -0.00463714 -0.37405708  0.00448513 -0.02684476  0.14538855
#   -0.00779895  0.1754191 ]
#  [ 0.43137282  0.00820552  0.84658234 -0.00517062  0.04844549 -0.2106598
#   -0.02501081 -0.22309575]
#  [-0.05590234  0.0268554   0.23224248  0.00262418  0.02619781 -0.18846191
#    0.09807771  0.94677706]
#  [-0.0066554  -0.01441117  0.06444165  0.05419767 -0.99589626  0.00194259
#   -0.02512911  0.01460498]
#  [ 0.02465459  0.09453374 -0.01155531  0.00713042 -0.02836918 -0.00859532
#    0.98945538 -0.10183577]]
# [ 1.23917822  0.12922697  1.04888625  0.06703106 -0.95444754  0.68765209
#   1.05275021  0.92247693]

# %%
#Factor Analysis Script + Run
from sklearn.decomposition import FactorAnalysis
import numpy as np

FA_model = FactorAnalysis(svd_method = 'lapack')
FA_model.n_components = 6
FA_fit = FA_model.fit(Purch_PCA)
print("covariance")
print(FA_fit.get_covariance())
print("precision")
print(FA_fit.get_precision())
# print("noise")
# print(FA_fit.noise_variance_)
# print('Loglike')
# print(FA_fit.loglike_)
print("components")
# matrix of size n_components X n_features
# a_i,j tells how much the jth feature contributed to the ith component
compFA = FA_fit.components_
print(compFA)
# summing along columns tells how much each feature contributes overall
comp_sum = np.sum(compFA, axis = 0)
print([p for p in comp_sum])
FA = FA_fit
# Out:
# covariance
# [[ 8.96282857e-02 -2.78780072e-04 -2.12916549e-03  1.18230376e-04
#   -5.54538174e-04 -3.32304656e-03 -1.88257326e-03  1.80457139e-03]
#  [-2.78780072e-04  3.52372299e-03  1.88617135e-03  1.30109509e-05
#    3.35970025e-04  2.32447105e-03  4.86860795e-04  1.42942042e-03]
#  [-2.12916549e-03  1.88617135e-03  9.13611276e-02 -2.50639627e-04
#    4.74027076e-03  2.13212981e-02  6.99327503e-04 -4.30848607e-03]
#  [ 1.18230376e-04  1.30109509e-05 -2.50639627e-04  6.34515748e-04
#   -9.22987600e-04  6.87345496e-04  5.17418655e-05  3.92052180e-04]
#  [-5.54538174e-04  3.35970025e-04  4.74027076e-03 -9.22987600e-04
#    1.76097788e-02  1.77239851e-03  3.96654164e-04  2.46300901e-04]
#  [-3.32304656e-03  2.32447105e-03  2.13212981e-02  6.87345496e-04
#    1.77239851e-03  1.52155158e-01  2.80282227e-03  1.27986193e-02]
#  [-1.88257326e-03  4.86860795e-04  6.99327503e-04  5.17418655e-05
#    3.96654164e-04  2.80282227e-03  7.01334972e-03  5.42587511e-03]
#  [ 1.80457139e-03  1.42942042e-03 -4.30848607e-03  3.92052180e-04
#    2.46300901e-04  1.27986193e-02  5.42587511e-03  6.06469199e-02]]
# precision
# [[ 1.12588083e+01  4.72624669e-01  1.31258005e-01 -1.98755138e+00
#    1.16134738e-01  2.21875154e-01  3.41962259e+00 -6.77213295e-01]
#  [ 4.72624669e-01  2.93122496e+02 -5.32022510e+00 -6.03953351e+00
#   -3.77321476e+00 -2.93988709e+00 -1.41084131e+01 -5.36377019e+00]
#  [ 1.31258005e-01 -5.32022510e+00  1.16590102e+01  1.63164949e+00
#   -2.78003742e+00 -1.62205866e+00 -1.03650646e+00  1.38555688e+00]
#  [-1.98755138e+00 -6.03953351e+00  1.63164949e+00  1.72460231e+03
#    9.11309730e+01 -8.14590889e+00 -8.12549497e+00 -8.75536267e+00]
#  [ 1.16134738e-01 -3.77321476e+00 -2.78003742e+00  9.11309730e+01
#    6.25209855e+01 -5.88010314e-01 -2.96540363e+00 -5.65655397e-01]
#  [ 2.21875154e-01 -2.93988709e+00 -1.62205866e+00 -8.14590889e+00
#   -5.88010314e-01  7.03094404e+00 -1.23028636e+00 -1.37120268e+00]
#  [ 3.41962259e+00 -1.41084131e+01 -1.03650646e+00 -8.12549497e+00
#   -2.96540363e+00 -1.23028636e+00  1.55710453e+02 -1.34495434e+01]
#  [-6.77213295e-01 -5.36377019e+00  1.38555688e+00 -8.75536267e+00
#   -5.65655397e-01 -1.37120268e+00 -1.34495434e+01  1.82854421e+01]]
# components
# [[-0.01572318  0.01367265  0.03627147  0.00305829  0.00630127  0.13462019
#    0.04055676  0.13782098]
#  [ 0.01758153 -0.0058304  -0.10153235  0.01162111 -0.06938914 -0.04231104
#   -0.00090212  0.02743627]
#  [-0.00820472  0.00577945  0.11880651  0.00658751 -0.02003509  0.12631641
#   -0.01144594 -0.0504245 ]
#  [ 0.09346385 -0.00056501 -0.01037011 -0.00034305  0.00756984  0.04408647
#   -0.01898598  0.03553586]
#  [-0.05467387 -0.00561616 -0.03697156 -0.00078105  0.00251374  0.06727711
#   -0.00677466  0.00352612]
#  [ 0.01567446 -0.01072611  0.00949679  0.00034503  0.0019173   0.00840236
#    0.00517809 -0.0033856 ]]
# [0.04811807839902306, -0.0032855787131112323, 0.01570076596605527, 0.020487836477646376, -0.07112209136839466, 0.3383914963929185, 0.0076261569343435524, 0.15050913540089542]

# %%
import matplotlib.pyplot as plt

# %%
# #Generate vars for plotting
# # PCA_feats = ['mean_unexpcost', 'mean_return', 'mean_qty', 'mean_costsave', 'mean_spend',
# #              'mean_leadtime', 'mean_abc', 'mean_source',
# #              'mean_late', 'mean_early','%Critical', 'quality_risk_mean', 'delivery_risk_mean']
# # uncost = [i[0] for i in comp]
# # ret = [i[1] for i in comp]
# # qty = [i[2] for i in comp]
# # costsave = [i[3] for i in comp]
# # spend = [i[4] for i in comp]
# # leadtime = [i[5] for i in comp]
# # abc = [i[6] for i in comp]
# # source = [i[7] for i in comp]
# # late = [i[8] for i in comp]
# # early = [i[9] for i in comp]
# # critical = [i[10] for i in comp]
# # qualrisk = [i[11] for i in comp]
# # delrisk = [i[12] for i in comp]

# PCA_feats = ['mean_unexpcost', 'mean_return','mean_spend',
#              'mean_late', 'mean_early','%Critical', 'quality_risk_mean', 'delivery_risk_mean']
# uncost = [i[0] for i in comp]
# ret = [i[1] for i in comp]
# spend = [i[2] for i in comp]
# late = [i[3] for i in comp]
# early = [i[4] for i in comp]
# critical = [i[5] for i in comp]
# qualrisk = [i[6] for i in comp]
# delrisk = [i[7] for i in comp]

# %%
# # PCA_feats = ['mean_unexpcost', 'mean_return', 'mean_qty', 'mean_costsave', 'mean_spend',
# #              'mean_leadtime', 'mean_abc', 'mean_source',
# #              'mean_late', 'mean_early','%Critical', 'quality_risk_mean', 'delivery_risk_mean']
# index = np.arange(8)
# error_config = {'ecolor': '0.3'}
# bw = 0.5
# op=0.9
# plt.figure(figsize=(10,5))
# rects8 = plt.bar(index, uncost, bw,
#                  alpha=op,
#                  color='black',
#                  error_kw=error_config,
#                  label='Unexpected Cost')
# rects1 = plt.bar(index, late, bw,
#                  alpha=op,
#                  color='b',
#                  error_kw=error_config,
#                  label='Late')
# rects2 = plt.bar(index, early,bw,
#                  alpha=op,
#                  color='r',
#                  error_kw=error_config,
#                  label='early')
# rects3 = plt.bar(index, critical, bw,
#                  alpha=op,
#                  color='orange',
#                  error_kw=error_config,
#                  label='critical')
# rects4 = plt.bar(index, spend, bw,
#                  alpha=op,
#                  color='black',
#                  error_kw=error_config,
#                  label='spend')
# rects5 = plt.bar(index, qualrisk, bw,
#                  alpha=op,
#                  color='c',
#                  error_kw=error_config,
#                  label='qualrisk')
# rects6 = plt.bar(index, delrisk, bw,
#                  alpha=op,
#                  color='y',
#                  error_kw=error_config,
#                  label='delrisk')
# rects7 = plt.bar(index, ret, bw,
#                  alpha=op,
#                  color='pink',
#                  error_kw=error_config,
#                  label='ret')
# plt.legend()
# plt.show()

# %%
#Varimax Algorithm
def varimax(Phi, gamma = 1.0, q = 20, tol = 1e-6):
    from numpy import eye, asarray, dot, sum, diag
    from numpy.linalg import svd
    p,k = Phi.shape
    R = eye(k)
    d=0
    for i in range(q):
        d_old = d
        Lambda = dot(Phi, R)
        u,s,vh = svd(dot(Phi.T,asarray(Lambda)**3 - (gamma/p) * dot(Lambda, diag(diag(dot(Lambda.T,Lambda))))))
        R = dot(u,vh)
        d = sum(s)
        if d/d_old < tol: break
    return dot(Phi, R)

# %%
sol = varimax(comp)
print(sol)
# Out:
# [[-1.09981468e-15 -9.75781955e-17  2.32452946e-15  8.89045781e-17
#    8.15320034e-17  1.00000000e+00 -3.13984949e-16  1.90125693e-15]
#  [ 1.00000000e+00  8.67361738e-19  6.24500451e-17  1.19262239e-18
#   -1.92120625e-16  1.32185929e-15 -1.87350135e-16  1.30451205e-15]
#  [ 4.85722573e-17  1.37910516e-16  1.00000000e+00  3.79470760e-17
#    4.99600361e-16 -2.11636264e-15 -1.97758476e-16 -2.13717932e-15]
#  [-1.47104551e-15 -6.24500451e-17  2.02615702e-15  2.41993925e-16
#    6.73072709e-16 -1.81799020e-15  1.40165657e-15  1.00000000e+00]
#  [-2.56739074e-16  6.59194921e-17  4.18068358e-16 -6.93889390e-17
#   -1.00000000e+00  4.03323208e-17 -1.18915294e-15  5.62050406e-16]
#  [ 2.98372438e-16  1.94289029e-16 -2.42861287e-16 -5.55111512e-17
#   -1.20303073e-15  4.82253126e-16  1.00000000e+00 -8.04911693e-16]]
# /software/anaconda3/5.3.0/lib/python3.7/site-packages/ipykernel/__main__.py:14: RuntimeWarning: divide by zero encountered in double_scalars

# %%
#Generate DFs
fa = pd.DataFrame(data = compFA,columns = PCA_feats)
orig = pd.DataFrame(data = comp,columns = PCA_feats)
varimax = pd.DataFrame(data = sol,columns = PCA_feats)
fa = fa.transpose()
orig = orig.transpose()
varimax = varimax.transpose()

colnames = ['comp1','comp2','comp3','comp4','comp5','comp6']
fa.columns = colnames
orig.columns = colnames
varimax.columns = colnames


# orig = pd.DataFrame(orig, columns = compnames)
# varimax = pd.DataFrame(varimax, columns = compnames)

# %%
print(list(fa))
fa
# Out:
# ['comp1', 'comp2', 'comp3', 'comp4', 'comp5', 'comp6']
#                        comp1     comp2     comp3     comp4     comp5     comp6
# mean_unexpcost     -0.015723  0.017582 -0.008205  0.093464 -0.054674  0.015674
# mean_return_spend   0.013673 -0.005830  0.005779 -0.000565 -0.005616 -0.010726
# mean_spend          0.036271 -0.101532  0.118807 -0.010370 -0.036972  0.009497
# mean_late           0.003058  0.011621  0.006588 -0.000343 -0.000781  0.000345
# mean_early          0.006301 -0.069389 -0.020035  0.007570  0.002514  0.001917
# %Critical           0.134620 -0.042311  0.126316  0.044086  0.067277  0.008402
# quality_risk_mean   0.040557 -0.000902 -0.011446 -0.018986 -0.006775  0.005178
# delivery_risk_mean  0.137821  0.027436 -0.050424  0.035536  0.003526 -0.003386

# %%
print(list(orig))
orig
# Out:
# ['comp1', 'comp2', 'comp3', 'comp4', 'comp5', 'comp6']
#                        comp1     comp2     comp3     comp4     comp5     comp6
# mean_unexpcost     -0.052817  0.898526  0.431373 -0.055902 -0.006655  0.024655
# mean_return_spend   0.018681 -0.004637  0.008206  0.026855 -0.014411  0.094534
# mean_spend          0.291232 -0.374057  0.846582  0.232242  0.064442 -0.011555
# mean_late           0.003764  0.004485 -0.005171  0.002624  0.054198  0.007130
# mean_early          0.022019 -0.026845  0.048445  0.026198 -0.995896 -0.028369
# %Critical           0.948038  0.145389 -0.210660 -0.188462  0.001943 -0.008595
# quality_risk_mean   0.023156 -0.007799 -0.025011  0.098078 -0.025129  0.989455
# delivery_risk_mean  0.110607  0.175419 -0.223096  0.946777  0.014605 -0.101836

# %%
# Out:
# ./prepared_data/join_binary_scale.csv

# %%
print(list(varimax))
varimax
# Out:
# ['comp1', 'comp2', 'comp3', 'comp4', 'comp5', 'comp6']
#                            comp1         comp2         comp3         comp4  \
# mean_unexpcost     -1.099815e-15  1.000000e+00  4.857226e-17 -1.471046e-15
# mean_return_spend  -9.757820e-17  8.673617e-19  1.379105e-16 -6.245005e-17
# mean_spend          2.324529e-15  6.245005e-17  1.000000e+00  2.026157e-15
# mean_late           8.890458e-17  1.192622e-18  3.794708e-17  2.419939e-16
# mean_early          8.153200e-17 -1.921206e-16  4.996004e-16  6.730727e-16
# %Critical           1.000000e+00  1.321859e-15 -2.116363e-15 -1.817990e-15
# quality_risk_mean  -3.139849e-16 -1.873501e-16 -1.977585e-16  1.401657e-15
# delivery_risk_mean  1.901257e-15  1.304512e-15 -2.137179e-15  1.000000e+00
#
#                            comp5         comp6
# mean_unexpcost     -2.567391e-16  2.983724e-16
# mean_return_spend   6.591949e-17  1.942890e-16
# mean_spend          4.180684e-16 -2.428613e-16
# mean_late          -6.938894e-17 -5.551115e-17
# mean_early         -1.000000e+00 -1.203031e-15
# %Critical           4.033232e-17  4.822531e-16
# quality_risk_mean  -1.189153e-15  1.000000e+00
# delivery_risk_mean  5.620504e-16 -8.049117e-16

# %%
PCA_feats[0]
# Out:
# 'mean_unexpcost'

# %%
def RowGen(data):
#     name = "join_with_scorecard2.csv"
#     feats = ['mean_unexpcost', 'mean_return_spend', 'mean_qty', 'mean_costsave', 'mean_spend',
#              'mean_leadtime','mean_abc', 'mean_source',
#              'mean_late', 'mean_early','%Critical', 'quality_risk_mean', 'delivery_risk_mean']
    feats = ['mean_unexpcost', 'mean_return_spend','mean_spend',
             'mean_late', 'mean_early','%Critical', 'quality_risk_mean', 'delivery_risk_mean']
    feats0 =['comp1','comp2','comp3','comp4','comp5','comp6']

    df = pd.read_csv(DATAFILE)
#     pd.to_numeric(df['median_return'], downcast = 'float')
    for feat in feats0:
        df[feat] = np.nan
        pd.to_numeric(df[feat], downcast = 'float')
    for i, row in df.iterrows():
        for c in feats0:
            k = 0
            for j,a,b in zip(list(range(0, 12)),feats,data.iterrows()):
#                 print(j + " ,"+ a)
                k = k + df[a][i] * data[c][j]
            df[c][i] = k
    df['RiskSum'] = np.nan
    pd.to_numeric(df['RiskSum'], downcast='float')
    for i, row in df.iterrows():
        k = 0
        for f in feats:
            k = k + df[f][i]
        df['RiskSum'][i] = k
    return df

# %%
# def RowGen2(data):
# #     name = "join_with_scorecard2.csv"
# #     feats = ['mean_unexpcost', 'mean_return_spend', 'mean_qty', 'mean_costsave', 'mean_spend',
# #              'mean_leadtime','mean_abc', 'mean_source',
# #              'mean_late', 'mean_early','%Critical', 'quality_risk_mean', 'delivery_risk_mean']
#     feats = ['mean_unexpcost', 'mean_return_spend','mean_spend',
#              'mean_late', 'mean_early','%Critical', 'quality_risk_mean', 'delivery_risk_mean']
#     feats0 =['comp1','comp2','comp3','comp4','comp5','comp6']

#     df = pd.read_csv(DATAFILE)
# #     pd.to_numeric(df['median_return'], downcast = 'float')
#     for feat in feats0:
#         df[feat] = np.nan
#         pd.to_numeric(df[feat], downcast = 'float')
#     i=0
#     c = feats0[0]
#     k = 0
# #     for j,a,b in zip(list(range(0, 12)),feats,data.iterrows()):
# #         print(j + " ,"+ a)
        
#     for a, row in zip(feats,data.iterrows()):
#         print(row)
#         print(row[1])
# #         k = k + df[a][i] * data[c][j]
# #     df[c][i] = k
# #     df['RiskSum'] = np.nan
# #     pd.to_numeric(df['RiskSum'], downcast='float')
# #     for i, row in df.iterrows():
# #         k = 0
# #         for f in feats:
# #             k = k + df[f][i]
# #         df['RiskSum'][i] = k
#     return df

# %%
# RowGen2(orig)
# Out:
# ('mean_unexpcost', comp1   -0.052817
# comp2    0.898526
# comp3    0.431373
# comp4   -0.055902
# comp5   -0.006655
# comp6    0.024655
# Name: mean_unexpcost, dtype: float64)
# comp1   -0.052817
# comp2    0.898526
# comp3    0.431373
# comp4   -0.055902
# comp5   -0.006655
# comp6    0.024655
# Name: mean_unexpcost, dtype: float64
# ('mean_return_spend', comp1    0.018681
# comp2   -0.004637
# comp3    0.008206
# comp4    0.026855
# comp5   -0.014411
# comp6    0.094534
# Name: mean_return_spend, dtype: float64)
# comp1    0.018681
# comp2   -0.004637
# comp3    0.008206
# comp4    0.026855
# comp5   -0.014411
# comp6    0.094534
# Name: mean_return_spend, dtype: float64
# ('mean_spend', comp1    0.291232
# comp2   -0.374057
# comp3    0.846582
# comp4    0.232242
# comp5    0.064442
# comp6   -0.011555
# Name: mean_spend, dtype: float64)
# comp1    0.291232
# comp2   -0.374057
# comp3    0.846582
# comp4    0.232242
# comp5    0.064442
# comp6   -0.011555
# Name: mean_spend, dtype: float64
# ('mean_late', comp1    0.003764
# comp2    0.004485
# comp3   -0.005171
# comp4    0.002624
# comp5    0.054198
# comp6    0.007130
# Name: mean_late, dtype: float64)
# comp1    0.003764
# comp2    0.004485
# comp3   -0.005171
# comp4    0.002624
# comp5    0.054198
# comp6    0.007130
# Name: mean_late, dtype: float64
# ('mean_early', comp1    0.022019
# comp2   -0.026845
# comp3    0.048445
# comp4    0.026198
# comp5   -0.995896
# comp6   -0.028369
# Name: mean_early, dtype: float64)
# comp1    0.022019
# comp2   -0.026845
# comp3    0.048445
# comp4    0.026198
# comp5   -0.995896
# comp6   -0.028369
# Name: mean_early, dtype: float64
# ('%Critical', comp1    0.948038
# comp2    0.145389
# comp3   -0.210660
# comp4   -0.188462
# comp5    0.001943
# comp6   -0.008595
# Name: %Critical, dtype: float64)
# comp1    0.948038
# comp2    0.145389
# comp3   -0.210660
# comp4   -0.188462
# comp5    0.001943
# comp6   -0.008595
# Name: %Critical, dtype: float64
# ('quality_risk_mean', comp1    0.023156
# comp2   -0.007799
# comp3   -0.025011
# comp4    0.098078
# comp5   -0.025129
# comp6    0.989455
# Name: quality_risk_mean, dtype: float64)
# comp1    0.023156
# comp2   -0.007799
# comp3   -0.025011
# comp4    0.098078
# comp5   -0.025129
# comp6    0.989455
# Name: quality_risk_mean, dtype: float64
# ('delivery_risk_mean', comp1    0.110607
# comp2    0.175419
# comp3   -0.223096
# comp4    0.946777
# comp5    0.014605
# comp6   -0.101836
# Name: delivery_risk_mean, dtype: float64)
# comp1    0.110607
# comp2    0.175419
# comp3   -0.223096
# comp4    0.946777
# comp5    0.014605
# comp6   -0.101836
# Name: delivery_risk_mean, dtype: float64
#      mean_unexpcost  median_unexpcost  mean_stdcost  median_stdcost  \
# 0          2.000000               2.0      2.000000             2.0
# 1          1.000000               1.0      2.000000             2.0
# 2          1.000000               1.0      1.000000             1.0
# 3          1.121053               1.0      2.000000             2.0
# 4          1.666667               2.0      1.111111             1.0
# 5          1.894737               2.0      2.000000             2.0
# 6          1.166667               1.0      2.000000             2.0
# 7          1.000000               1.0      1.000000             1.0
# 8          1.000000               1.0      2.000000             2.0
# 9          1.333333               1.0      2.000000             2.0
# 10         1.363636               1.0      1.818182             2.0
# 15               1.5  ...             1.000000                  1.0
# 16               2.0  ...             1.000000                  1.0
# 17               2.0  ...             1.000000                  1.0
# 18               2.0  ...             1.000000                  1.0
# 19               2.0  ...             1.000000                  1.0
# 20               2.0  ...             1.000000                  1.0
# 21               2.0  ...             1.000000                  1.0
# 22               1.0  ...             1.000000                  1.0
# 23               1.0  ...             1.000000                  1.0
# 24               2.0  ...             1.000000                  1.0
# 25               2.0  ...             1.000000                  1.0
# 26               2.0  ...             1.000000                  1.0
# 27               1.0  ...             1.000000                  1.0
# 28               2.0  ...             1.125000                  1.0
# 29               2.0  ...             1.125000                  1.0
# ..               ...  ...                  ...                  ...
# 548              2.0  ...             1.000000                  1.0
# 549              2.0  ...             1.500000                  1.5
# 550              2.0  ...             1.136364                  1.0
# 551              2.0  ...             1.136364                  1.0
# 552              2.0  ...             1.090909                  1.0
# 553              1.0  ...             1.000000                  1.0
# 554              2.0  ...             1.000000                  1.0
# 555              2.0  ...             1.000000                  1.0
# 556              2.0  ...             1.000000                  1.0
# 557              2.0  ...             1.000000                  1.0
# 558              2.0  ...             1.000000                  1.0
# 559              2.0  ...             1.222222                  1.0
# 560              2.0  ...             1.222222                  1.0
# 561              2.0  ...             1.000000                  1.0
# 562              2.0  ...             1.083333                  1.0
# 563              2.0  ...             1.055556                  1.0
# 564              2.0  ...             1.055556                  1.0
# 565              2.0  ...             1.000000                  1.0
# 566              2.0  ...             1.000000                  1.0
# 567              2.0  ...             1.000000                  1.0
# 568              2.0  ...             1.000000                  1.0
# 569              2.0  ...             1.111111                  1.0
# 570              2.0  ...             1.000000                  1.0
# 571              2.0  ...             2.000000                  2.0
# 572              1.0  ...             1.000000                  1.0
# 573              1.0  ...             1.000000                  1.0
# 574              2.0  ...             1.000000                  1.0
# 575              2.0  ...             1.000000                  1.0
# 576              2.0  ...             1.000000                  1.0
# 577              1.0  ...             1.000000                  1.0
#
#      delivery_risk_mean  delivery_risk_median  comp1  comp2  comp3  comp4  \
# 0              1.000000                   1.0    NaN    NaN    NaN    NaN
# 1              1.000000                   1.0    NaN    NaN    NaN    NaN
# 2              1.000000                   1.0    NaN    NaN    NaN    NaN
# 3              1.391304                   1.0    NaN    NaN    NaN    NaN
# 4              1.083333                   1.0    NaN    NaN    NaN    NaN
# 5              1.176471                   1.0    NaN    NaN    NaN    NaN
# 6              1.176471                   1.0    NaN    NaN    NaN    NaN
# 7              1.750000                   2.0    NaN    NaN    NaN    NaN
# 8              1.750000                   2.0    NaN    NaN    NaN    NaN
# 9              1.750000                   2.0    NaN    NaN    NaN    NaN
# 10             1.750000                   2.0    NaN    NaN    NaN    NaN
# 11             1.416667                   1.0    NaN    NaN    NaN    NaN
# 12             1.416667                   1.0    NaN    NaN    NaN    NaN
# 13             1.416667                   1.0    NaN    NaN    NaN    NaN
# 14             1.416667                   1.0    NaN    NaN    NaN    NaN
# 15             1.416667                   1.0    NaN    NaN    NaN    NaN
# 16             1.333333                   1.0    NaN    NaN    NaN    NaN
# 17             1.250000                   1.0    NaN    NaN    NaN    NaN
# 26     NaN    NaN
# 27     NaN    NaN
# 28     NaN    NaN
# 29     NaN    NaN
# ..     ...    ...
# 548    NaN    NaN
# 549    NaN    NaN
# 550    NaN    NaN
# 551    NaN    NaN
# 552    NaN    NaN
# 553    NaN    NaN
# 554    NaN    NaN
# 555    NaN    NaN
# 556    NaN    NaN
# 557    NaN    NaN
# 558    NaN    NaN
# 559    NaN    NaN
# 560    NaN    NaN
# 561    NaN    NaN
# 562    NaN    NaN
# 563    NaN    NaN
# 564    NaN    NaN
# 565    NaN    NaN
# 566    NaN    NaN
# 567    NaN    NaN
# 568    NaN    NaN
# 569    NaN    NaN
# 570    NaN    NaN
# 571    NaN    NaN
# 572    NaN    NaN
# 573    NaN    NaN
# 574    NaN    NaN
# 575    NaN    NaN
# 576    NaN    NaN
# 577    NaN    NaN
#
# [578 rows x 37 columns]

# %%
df_orig = RowGen(orig)
df_orig

# %%
df_varimax = RowGen(varimax)
df_varimax
# Out:
# /software/anaconda3/5.3.0/lib/python3.7/site-packages/ipykernel/__main__.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /software/anaconda3/5.3.0/lib/python3.7/site-packages/ipykernel/__main__.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      mean_unexpcost  median_unexpcost  mean_stdcost  median_stdcost  \
# 0          2.000000               2.0      2.000000             2.0
# 1          1.000000               1.0      2.000000             2.0
# 2          1.000000               1.0      1.000000             1.0
# 3          1.121053               1.0      2.000000             2.0
# 4          1.666667               2.0      1.111111             1.0
# 5          1.894737               2.0      2.000000             2.0
# 6          1.166667               1.0      2.000000             2.0
# 7          1.000000               1.0      1.000000             1.0
# 8          1.000000               1.0      2.000000             2.0
# 9          1.333333               1.0      2.000000             2.0
# 10         1.363636               1.0      1.818182             2.0
# 11         2.000000               2.0      2.000000             2.0
# 12         1.166667               1.0      1.000000             1.0
# 13         1.470588               1.0      1.000000             1.0
# 14         1.305795               1.0      1.129470             1.0
# 15         1.500000               1.5      1.000000             1.0
# 16         1.000000               1.0      2.000000             2.0
# 17         1.500000               1.5      2.000000             2.0
# 18         1.239544               1.0      1.182510             1.0
# 19         1.260000               1.0      1.340000             1.0
# 20         1.555556               2.0      1.222222             1.0
# 21         1.000000               1.0      2.000000             2.0
# 22         1.333333               1.0      2.000000             2.0
# 23         1.666667               2.0      2.000000             2.0
# 24         2.000000               2.0      1.000000             1.0
# 25         2.000000               2.0      1.000000             1.0
# 26         1.750000               2.0      1.000000             1.0
# 27         1.000000               1.0      1.000000             1.0
# 28         1.375000               1.0      2.000000             2.0
# 29         1.000000               1.0      1.000000             1.0
# ..              ...               ...           ...             ...
# 548        2.000000               2.0      1.000000             1.0
# 549        1.705882               2.0      1.647059             2.0
# 550        1.257895               1.0      1.926316             2.0
# 551        1.000000               1.0      2.000000             2.0
# 552        1.416667               1.0      2.000000             2.0
# 553        1.000000               1.0      1.000000             1.0
# 554        1.345238               1.0      1.071429             1.0
# 555        1.373563               1.0      1.383142             1.0
# 556        1.000000               1.0      1.200000             1.0
# 557        1.000000               1.0      1.000000             1.0
# 558        1.357143               1.0      1.285714             1.0
# 559        1.428571               1.0      2.000000             2.0
# 560        1.705882               2.0      2.000000             2.0
# 560     2.000000            2.0  1.000000         1.0       2.000000
# 561     1.729167            2.0  1.604167         2.0       1.937500
# 562     2.000000            2.0  1.000000         1.0       2.000000
# 563     1.000000            1.0  2.000000         2.0       1.848485
# 564     1.105769            1.0  1.774038         2.0       1.802885
# 565     2.000000            2.0  1.000000         1.0       2.000000
# 566     2.000000            2.0  1.031250         1.0       2.000000
# 567     2.000000            2.0  1.000000         1.0       1.636364
# 568     1.000000            1.0  2.000000         2.0       1.666667
# 569     2.000000            2.0  1.037736         1.0       2.000000
# 570     2.000000            2.0  1.181818         1.0       2.000000
# 571     2.000000            2.0  1.000000         1.0       2.000000
# 572     2.000000            2.0  1.758621         2.0       1.379310
# 573     1.064516            1.0  1.790323         2.0       1.338710
# 574     1.230769            1.0  1.846154         2.0       1.769231
# 575     2.000000            2.0  1.000000         1.0       1.916667
# 576     2.000000            2.0  1.000000         1.0       2.000000
# 577     1.000000            1.0  2.000000         2.0       1.000000
#
#      median_costsave    ...      quality_risk_median  delivery_risk_mean  \
# 0                2.0    ...                      1.0            1.000000
# 1                2.0    ...                      1.0            1.000000
# 2                2.0    ...                      1.0            1.000000
# 3                2.0    ...                      1.0            1.391304
# 4                1.0    ...                      1.0            1.083333
# 5                1.0    ...                      1.0            1.176471
# 6                2.0    ...                      1.0            1.176471
# 7                2.0    ...                      1.0            1.750000
# 8                2.0    ...                      1.0            1.750000
# 9                2.0    ...                      1.0            1.750000
# 10               2.0    ...                      1.0            1.750000
# 11               2.0    ...                      1.0            1.416667
# 12               1.5    ...                      1.0            1.416667
# 13               1.0    ...                      1.0            1.416667
# 14               2.0    ...                      1.0            1.416667
# 15               1.5    ...                      1.0            1.416667
# 16               2.0    ...                      1.0            1.333333
# 17               2.0    ...                      1.0            1.250000
# 18               2.0    ...                      1.0            1.250000
# 19               2.0    ...                      1.0            1.250000
# 20               2.0    ...                      1.0            1.250000
# 21               2.0    ...                      1.0            1.307692
# 22               1.0    ...                      1.0            1.307692
# 23               1.0    ...                      1.0            1.000000
# 24               2.0    ...                      1.0            1.000000
# 25               2.0    ...                      1.0            1.000000
# 26               2.0    ...                      1.0            1.000000
# 27               1.0    ...                      1.0            1.000000
# 28               2.0    ...                      1.0            1.666667
# 29               2.0    ...                      1.0            1.666667
# ..               ...    ...                      ...                 ...
# 548              2.0    ...                      1.0            1.333333
# 549              2.0    ...                      1.5            2.000000
# 550              2.0    ...                      1.0            1.590909
# 551              2.0    ...                      1.0            1.590909
# 552              2.0    ...                      1.0            1.090909
# 553              1.0    ...                      1.0            1.200000
# 554              2.0    ...                      1.0            1.083333
# 555              2.0    ...                      1.0            1.083333
# 556              2.0    ...                      1.0            1.083333
# 557              2.0    ...                      1.0            1.083333
# 558              2.0    ...                      1.0            1.083333
# 559              2.0    ...                      1.0            1.666667
# 560              2.0    ...                      1.0            1.666667
# 561              2.0    ...                      1.0            1.400000
# 562              2.0    ...                      1.0            1.000000
# 563              2.0    ...                      1.0            1.555556
# 564              2.0    ...                      1.0            1.555556
# 565              2.0    ...                      1.0            1.000000
# 566              2.0    ...                      1.0            1.000000
# 574     1.230769            1.0  1.846154         2.0       1.769231
# 575     2.000000            2.0  1.000000         1.0       1.916667
# 576     2.000000            2.0  1.000000         1.0       2.000000
# 577     1.000000            1.0  2.000000         2.0       1.000000
#
#      median_costsave    ...      quality_risk_median  delivery_risk_mean  \
# 0                2.0    ...                      1.0            1.000000
# 1                2.0    ...                      1.0            1.000000
# 2                2.0    ...                      1.0            1.000000
# 3                2.0    ...                      1.0            1.391304
# 4                1.0    ...                      1.0            1.083333
# 5                1.0    ...                      1.0            1.176471
# 6                2.0    ...                      1.0            1.176471
# 7                2.0    ...                      1.0            1.750000
# 8                2.0    ...                      1.0            1.750000
# 9                2.0    ...                      1.0            1.750000
# 10               2.0    ...                      1.0            1.750000
# 11               2.0    ...                      1.0            1.416667
# 12               1.5    ...                      1.0            1.416667
# 13               1.0    ...                      1.0            1.416667
# 14               2.0    ...                      1.0            1.416667
# 15               1.5    ...                      1.0            1.416667
# 16               2.0    ...                      1.0            1.333333
# 17               2.0    ...                      1.0            1.250000
# 18               2.0    ...                      1.0            1.250000
# 19               2.0    ...                      1.0            1.250000
# 20               2.0    ...                      1.0            1.250000
# 21               2.0    ...                      1.0            1.307692
# 22               1.0    ...                      1.0            1.307692
# 23               1.0    ...                      1.0            1.000000
# 24               2.0    ...                      1.0            1.000000
# 25               2.0    ...                      1.0            1.000000
# 26               2.0    ...                      1.0            1.000000
# 27               1.0    ...                      1.0            1.000000
# 28               2.0    ...                      1.0            1.666667
# 29               2.0    ...                      1.0            1.666667
# ..               ...    ...                      ...                 ...
# 548              2.0    ...                      1.0            1.333333
# 549              2.0    ...                      1.5            2.000000
# 550              2.0    ...                      1.0            1.590909
# 551              2.0    ...                      1.0            1.590909
# 552              2.0    ...                      1.0            1.090909
# 553              1.0    ...                      1.0            1.200000
# 554              2.0    ...                      1.0            1.083333
# 555              2.0    ...                      1.0            1.083333
# 556              2.0    ...                      1.0            1.083333
# 557              2.0    ...                      1.0            1.083333
# 558              2.0    ...                      1.0            1.083333
# 559              2.0    ...                      1.0            1.666667
# 560              2.0    ...                      1.0            1.666667
# 561              2.0    ...                      1.0            1.400000
# 562              2.0    ...                      1.0            1.000000
# 563              2.0    ...                      1.0            1.555556
# 564              2.0    ...                      1.0            1.555556
# 565              2.0    ...                      1.0            1.000000
# 566              2.0    ...                      1.0            1.000000
# 567              2.0    ...                      1.0            1.250000
# 568              2.0    ...                      1.0            1.000000
# 569              2.0    ...                      1.0            1.888889
# 570              2.0    ...                      1.0            1.000000
# 571              2.0    ...                      2.0            1.000000
# 572              1.0    ...                      1.0            1.250000
# 573              1.0    ...                      1.0            1.500000
# 574              2.0    ...                      1.0            1.200000
# 575              2.0    ...                      1.0            1.000000
# 576              2.0    ...                      1.0            1.333333
# 577              1.0    ...                      1.0            2.000000
#
#      delivery_risk_median     comp1     comp2     comp3     comp4     comp5  \
# 0                     1.0  0.347157 -0.215134  0.139140  0.251426 -0.083660
# 1                     1.0  0.370691 -0.233352  0.178339  0.153853 -0.037766
# 2                     1.0  0.497500 -0.275026  0.273661  0.202048  0.038291
# 564                   2.0  0.574490 -0.257899  0.244510  0.234155  0.031702
# 565                   1.0  0.355664 -0.223596  0.143429  0.209823 -0.059985
# 566                   1.0  0.377535 -0.280608  0.207926  0.187449 -0.069657
# 567                   1.0  0.534393 -0.289627  0.298154  0.300420 -0.030988
# 568                   1.0  0.362880 -0.232715  0.147345  0.157962 -0.028987
# 569                   2.0  0.626139 -0.262156  0.244408  0.256304  0.019163
# 570                   1.0  0.369475 -0.251176  0.168946  0.156076 -0.035709
# 571                   1.0  0.395575 -0.224827  0.131796  0.185708 -0.063098
# 572                   1.0  0.396599 -0.220322  0.152702  0.196091 -0.052948
# 573                   1.5  0.432133 -0.221043  0.125490  0.182914 -0.033007
# 574                   1.0  0.382720 -0.227972  0.148595  0.242558 -0.080232
# 575                   1.0  0.371621 -0.279810  0.214217  0.241003 -0.104958
# 576                   1.0  0.416986 -0.244265  0.154683  0.167695 -0.035580
# 577                   2.0  0.500701 -0.205279  0.096920  0.193498 -0.025460
#
#         comp6    RiskSum
# 0    0.044494  10.000000
# 1    0.029253   9.300000
# 2    0.037222  10.000000
# 3    0.045321  11.340857
# 4    0.046725  10.564815
# 5    0.043863  10.081734
# 6    0.030835   9.343137
# 7    0.026712   9.833333
# 8    0.026712   9.833333
# 9    0.046670  11.833333
# 10   0.032356  10.287879
# 11   0.045453  10.562094
# 12   0.029747   9.440476
# 13   0.033523  10.004902
# 14   0.031925   9.686895
# 15   0.035246   9.916667
# 16   0.036353  10.290780
# 17   0.035810   9.750000
# 18   0.031836   9.485885
# 19   0.031056   9.388182
# 20   0.036681   9.805556
# 21   0.043088  11.157960
# 22   0.038142  10.418803
# 23   0.045600  10.333333
# 24   0.044494  10.000000
# 25   0.044494  10.000000
# 26   0.040575   9.750000
# 27   0.028820   9.000000
# 28   0.041171  11.000000
# 29   0.027210   9.791667
# ..        ...        ...
# 548  0.043366  10.333333
# 549  0.037414  11.302941
# 550  0.034602  10.416746
# 551  0.027525   9.727273
# 552  0.043428  10.431818
# 553  0.028143   9.200000
# 554  0.033725   9.390476
# 555  0.034244   9.404519
# 556  0.028537   9.083333
# 557  0.028537   9.083333
# 558  0.033752   9.240476
# 559  0.035436  11.031746
# 560  0.045918  11.712418
# 561  0.029840   9.650000
# 562  0.044530  10.981293
# 563  0.042051  10.580808
# 564  0.037729  10.779380
# 565  0.036336   9.666667
# 566  0.038737  10.000000
# 567  0.051603  11.977273
# 568  0.028820   9.000000
# 569  0.040545  11.462264
# 570  0.030546   9.181818
# 571  0.041835  10.500000
# 572  0.033565   9.601724
# 573  0.028351   9.645161
# 574  0.042867  10.200000
# 575  0.048883  10.666667
# 576  0.028875   9.600000
# 577  0.025434  10.000000
#
# [578 rows x 38 columns]

# %%
# df_pca.to_csv("PCA_reduced_orig.csv", index = False)
# df_varimax.to_csv("PCA_reduced_varimax.csv", index = False)
# df_fa.to_csv("FA_reduced.csv", index = False)

# %%
X = Purch_PCA
pca = PCA(n_components = 6)
x = pca.fit_transform(X)
x
# Out:
# array([[-0.307737  ,  0.6539318 ,  0.22406895, -0.30288168, -0.07727372,
#          0.00406984],
#        [-0.19936908, -0.31203661, -0.05057088, -0.20373872,  0.20335238,
#         -0.00456754],
#        [ 0.69311817, -0.0992054 , -0.41796367, -0.43544126, -0.06867572,
#         -0.02918007],
#        ...,
#        [-0.12195946,  0.38232113,  0.73589283, -0.15316292, -0.03792131,
#          0.0036983 ],
#        [-0.15855889, -0.26124148, -0.11180562,  0.11685186, -0.0538224 ,
#         -0.05053882],
#        [-0.14431249, -0.06917485, -0.43039962,  0.69979771, -0.05601333,
#         -0.12242052]])

# %%
# params

# %%
# comp_sum

# %%
# fa.to_csv("FA.csv", index = False)
# orig.to_csv("PCA_original.csv", index = False)
# varimax.to_csv("PCA_Varimax.csv", index = False)
# np.savetxt("PCA_explainedvariance.csv", params, delimiter=",")

# %%
# print(sol)

# %% [markdown]
# #### Tsne

# %%
# def Labels_to_color (df, classif,label_col):
#     """
#     For a dataframe (df) and its classification (classif) it 
#     turns each class label to numerical values and returns the dataframe
#     """
    
#     ClassList= df[classif].unique()
#     id = 0
#     color = ['b', 'g', 'r', 'y',  'w', 'c']

#     marker = ['o','x','+','^','s','v']
#     ClassDict = {}
#     for ClassVal in ClassList:
        
#         ClassDict[ClassVal]= color[id]
#         id = id+1
#     print(ClassDict)
#     for ClassNum in ClassDict.keys():
#         df.ix[df[classif]==ClassNum,label_col] = ClassDict[ClassNum]
#         print (ClassDict[ClassNum])
#     df=df.drop(classif,axis =1)
#     print(df[label_col].unique())
        
#     return df

# %%
# q23 = 0
# q24 = 1
# if(q24/q23 < 2):
#     print (q23)

# %%
# pca=PCA_method(Purch_PCA) 
# comp = pca.components_

# %%
# pca = PCA(n_components=6)
# X = Purch_PCA
# pca.fit(X)
# X_pca = pca.transform(X)
# print("original shape:   ", X.shape)
# print("transformed shape:", X_pca.shape)
# df_pca= pd.DataFrame(X_pca)
# print(df_pca)
# print(X_pca)
# # q.transform()

# %%
# X_new = pca.inverse_transform(X_pca)
# plt.scatter(X[:, 0], X[:, 1], alpha=0.2)
# plt.scatter(X_new[:, 0], X_new[:, 1], alpha=0.8)
# plt.axis('equal');
# # print(list(X_new))

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
# rng = np.random.RandomState(1)
# X = np.dot(rng.rand(2, 2), rng.randn(2, 200)).T
X = Purch_PCA.as_matrix()
plt.scatter(X[:, 0], X[:, 1])
plt.axis('equal');
# Out:
# /software/anaconda3/5.3.0/lib/python3.7/site-packages/ipykernel/__main__.py:3: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   app.launch_new_instance()

# %%
pca = PCA(n_components=6)
pca.fit(x)
print(pca.components_)
print(pca.explained_variance_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-af95e270d9bf> in <module>()
#       1 pca = PCA(n_components=6)
# ----> 2 pca.fit(x)
#       3 print(pca.components_)
#       4 print(pca.explained_variance_)
#
# NameError: name 'x' is not defined

# %%
# pca=PCA_method(Purch_PCA) 
pca = PCA(n_components=6)
pca.fit(x)
X_pca = pca.transform(X)
print("original shape:   ", X.shape)
print("transformed shape:", X_pca.shape)

# %%
X_new = pca.inverse_transform(X_pca)
plt.scatter(X[:, 0], X[:, 1], alpha=0.2)
plt.scatter(X_new[:, 0], X_new[:, 1], alpha=0.8)
plt.axis('equal');
